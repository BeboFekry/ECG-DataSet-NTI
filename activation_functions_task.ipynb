# %% [markdown]
# <a href="https://colab.research.google.com/github/BeboFekry/ECG-DataSet-NTI/blob/main/activation_functions_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import packages

# %%
import numpy as np

# %% [markdown]
# #Calculate functions
# ![relu d.PNG](data:image/png;base64,...)
# ![softmax function.PNG](data:image/png;base64,...)![sigmoid functionn.PNG](data:image/png;base64,...)

# %%
def sigmoid(z):
  return 1/(z+np.exp(-z))

# %%
def softmax(z):

  return 1/(z+np.exp(-z))

# %%
def relu(z):

  return

# %% [markdown]
# # Calculate outputs

# %%
z = [-0.5, 1.2, -0.1, 2.4]
sig = sigmoid(z)
soft = softmax(z)
r = relu(z)

# %%
sig

# %%
soft

# %%
r

# %% [markdown]
# # Correct outputs
# sigmoid = [0.37754067, 0.76852478, 0.47502081, 0.9168273 ]
#
# softmax = [0.03825567, 0.20940951, 0.05707075, 0.69526407]
#
# relu = [0. , 1.2, 0. , 2.4]

# %% [markdown]
# # Calculate sum of values outputted from softmax and sigmoid functions

# %%
# Out:
# 2.5379135683243006

# %%
# Out:
# 1.0

# %% [markdown]
# #Display the class

# %%
# Out:
# 3

# %%
# Out:
# 3
